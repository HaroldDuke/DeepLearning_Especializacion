# %%
#Importar librerías
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

# %%
#Cargar datos
#Dataset de ropa (camisetas, zapatos, etc)
fashion_mnist=keras.datasets.fashion_mnist

(x_train, y_train), (x_test, y_test)=fashion_mnist.load_data()

#Normalizar datos (0 a 1)
x_train=x_train/255.0
x_test=x_test/255.0
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
#Crear modelo
def create_model():
      model=keras.Sequential([
            keras.layers.Flatten(input_shape=(28,28)),
            keras.layers.Dense(128, activation='relu'),
            keras.layers.Dense(10, activation='softmax')
      ])
      return model

# %%
#Experimento A (Learning rate ALTO)
modelo_A = create_model()
modelo_A.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.01),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

historia_A=modelo_A.fit(
    x_train, y_train,
    epochs=10,
    batch_size=32,
    validation_data=(x_test, y_test)
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8152 - loss: 0.5198 - val_accuracy: 0.8313 - val_loss: 0.4855
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8450 - loss: 0.4318 - val_accuracy: 0.8310 - val_loss: 0.4635
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8528 - loss: 0.4121 - val_accuracy: 0.8385 - val_loss: 0.4675
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8568 - loss: 0.4038 - val_accuracy: 0.8410 - val_loss: 0.4740
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8602 - loss: 0.3893 - val_accuracy: 0.8443 - val_loss: 0.4435
# Epoch 6/10
# ...

# %%
#Experimento B (Learning rate BAJO)
modelo_B=create_model()

modelo_B.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

historia_B=modelo_B.fit(
    x_train, y_train,
    epochs=10,
    batch_size=32,
    validation_data=(x_test, y_test)
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8238 - loss: 0.4965 - val_accuracy: 0.8445 - val_loss: 0.4408
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8644 - loss: 0.3743 - val_accuracy: 0.8640 - val_loss: 0.3869
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8784 - loss: 0.3347 - val_accuracy: 0.8664 - val_loss: 0.3844
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8863 - loss: 0.3093 - val_accuracy: 0.8707 - val_loss: 0.3602
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8921 - loss: 0.2907 - val_accuracy: 0.8707 - val_loss: 0.3516
# Epoch 6/10
# ...

# %%
#Graficar resultados
#LOSS
plt.figure()
plt.plot(historia_A.history['loss'], label='Loss A (lr=0.01)')
plt.plot(historia_B.history['loss'], label='Loss B (lr=0.001)')
plt.title('Comparación de Loss')
plt.xlabel('Épocas')
plt.ylabel('Loss')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#ACURRACY
plt.figure()
plt.plot(historia_A.history['accuracy'], label='Acc A (lr=0.01)')
plt.plot(historia_B.history['accuracy'], label='Acc B (lr=0.001)')
plt.title('Comparación de Accurracy')
plt.xlabel('Épocas')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#EVALUACIÓN FINAL
print("Evaluación modelo A:")
modelo_A.evaluate(x_test, y_test)

print("Evaluación modelo B:")
modelo_B.evaluate(x_test, y_test)
# Out:
# Evaluación modelo A:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8371 - loss: 0.4700
# Evaluación modelo B:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8787 - loss: 0.3505
# [0.350533127784729, 0.8787000179290771]
